# %% [markdown]
# # Hashtag based Tweet Search

# %%
# read tweets from file
file = open("australian_election_2019_tweets.txt", "r")
tweets = file.readlines()
file.close()

# Remove duplicate tweets by using set
tweets = list(set(tweets))

# show some tweets
tweets[:5]
# Out:
# ['The last election was held on my 21st birthday, I stayed in the hotel room watching election coverage until it was called and then drank my sorrows away at the club.\n',
#  'Huge yarn from @politico - Australia allegedly took in mass murderers in exchange for sending asylum seekers on Nauru and Manus to the US. Australia’s secret US refugee deal faces blowback from victims, Kiwis – POLITICO via \u2066@zoyashef\u2069 #auspol  https://t.co/cgR0h0nceT\n',
#  'C’mon @TheWeeklyTV We need a clip of that Liberal Party PR team. Comedy GOLD! #TheWeekly #auspol\n',
#  'Primary Votes: ALP 38.7 (-13.1) NAT 21.9 (-4.4) ON 21.8 (+21.8) GRN 7.2 (+0.1) UAP 4.2 (+4.2)\n',
#  '#ausvotes https://t.co/Hty7S5zwFJ\n']

# %% [markdown]
# Here I load the file, remove duplicates using set() function, and perform a sanity check for tweets.

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import re
from nltk.corpus import words

english_words = set(words.words())

# Function to clean tweets (URLS, mentions, hastags, non-english text)
def clean_tweet(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove mentions
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    # Remove non-English text
    words_in_text = text.split()
    english_text = ' '.join(word for word in words_in_text if word.lower() in english_words)
    return english_text

# Clean tweets
cleaned_tweets = [clean_tweet(tweet) for tweet in tweets]

# Display the first few cleaned tweets to verify
cleaned_tweets[:5]
# Out:
# ['The last election was on my I stayed in the hotel room watching election coverage until it was and then drank my away at the',
#  'Huge yarn from allegedly took in mass in exchange for sending asylum on and Manus to the secret US refugee deal blowback from POLITICO via',
#  'We need a clip of that Liberal Party Comedy',
#  'Primary ALP NAT ON',
#  '']

# %% [markdown]
# Here I define a function to clean tweets by removing URLS, mentions, hastags and non-english text. I implement the function on all the tweets and perform a sanity check.

# %%
hashtag_list = [
    "#RenewableEnergy",
    "#TaxLaws",
    "#PoliticalAdvertising",
    "#AustraliaCricket",
    "#VotingRights",
    "#politics",
    "#trump",
    "#abortion",
    "#climate",
    "#ashes",
]


def do_process_eng_hashtag(input_text: str) -> str:
    return re.sub(
        r'#[A-Za-z0-9]+',
        lambda m: ' '.join(re.findall('[A-Z][^A-Z]*|[a-z][^A-Z]*', m.group().lstrip('#'))),
        input_text,)


clean_hashtags = [do_process_eng_hashtag(hashtag) for hashtag in hashtag_list]
clean_hashtags
# Out:
# ['Renewable Energy',
#  'Tax Laws',
#  'Political Advertising',
#  'Australia Cricket',
#  'Voting Rights',
#  'politics',
#  'trump',
#  'abortion',
#  'climate',
#  'ashes']

# %% [markdown]
# Here I define a hashtag list that I will use to conduct my search. I also define a function to process each hashtag.

# %%
# Convert to lowercase
def clean_and_lowercase_text(text):
    text = text.lower()
    return text


clean_tweets = [clean_and_lowercase_text(tweet) for tweet in cleaned_tweets]
cleaned_hashtags = [clean_and_lowercase_text(hashtag) for hashtag in clean_hashtags]

# %% [markdown]
# Here I define and implement a lowercasing function.

# %%
import nltk

# these datasets that NLTK needs to tokenize should be downloaded once.
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

def my_tokenize(text):
  tokenized_text = word_tokenize(text)
  return " ".join(tokenized_text)

tokenized_cleaned_tweets = [my_tokenize(tweet) for tweet in clean_tweets[:5]]
tokenized_cleaned_hashtags = [my_tokenize(hashtag) for hashtag in cleaned_hashtags]

print(tokenized_cleaned_tweets[:5])
print(tokenized_cleaned_hashtags[:5])
# Out:
# ['the last election was on my i stayed in the hotel room watching election coverage until it was and then drank my away at the', 'huge yarn from allegedly took in mass in exchange for sending asylum on and manus to the secret us refugee deal blowback from politico via', 'we need a clip of that liberal party comedy', 'primary alp nat on', '']
# ['renewable energy', 'tax laws', 'political advertising', 'australia cricket', 'voting rights']

# %% [markdown]
# Here I define and implement a tokenizing function.

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
ps = PorterStemmer()


def stem_text_and_remove_stop_words(text):
  text = my_tokenize(text)
  tokens = text.split()
  stemmed_words = []

  for token in tokens:
    if token not in stop_words:
      stemmed_token = ps.stem(token)
      stemmed_words.append(stemmed_token)
  return " ".join(stemmed_words)


stemmed_tweets = [stem_text_and_remove_stop_words(tweet) for tweet in clean_tweets]
stemmed_hashtags = [stem_text_and_remove_stop_words(hashtag) for hashtag in cleaned_hashtags]
print(stemmed_tweets[:5])
print(stemmed_hashtags[:5])
# Out:
# ['last elect stay hotel room watch elect coverag drank away', 'huge yarn allegedli took mass exchang send asylum manu secret us refuge deal blowback politico via', 'need clip liber parti comedi', 'primari alp nat', '']
# ['renew energi', 'tax law', 'polit advertis', 'australia cricket', 'vote right']

# %% [markdown]
# Here I define and implement a stemming function and remove stopwords form the tweets.

# %% [markdown]
# # Task 1: Use CountVectorizer (binary = true) vectorization technique and perform search

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import pairwise_distances
import numpy as np

# Function to retrieve top n_similar tweets for a given hashtag using sklearn's CountVectorizer
def find_similar_tweets_using_countvectorizer(hashtag, n_similar=10):

  # Define the N for N-grams
  N = 1

  # Initialize CountVectorizer with N and binary=True
  vectorizer = CountVectorizer(ngram_range=(N, N), lowercase=False, binary=True)

  # Fit vectorizer using stemmed tweets
  vectorizer.fit(stemmed_tweets)

  # Vectorize the hashtag using the fitted vectorizer
  queryVector = vectorizer.transform([hashtag.lower()]).toarray()

  # Calculate similarity score using inverse Euclidean distance (built-in sklearn)
  distances = 1 / (1 + pairwise_distances(queryVector, vectorizer.transform(stemmed_tweets), metric='euclidean'))[0]

  # Sort indices
  sorted_indices = np.argsort(distances)

  # Return the top n_similar tweets and scores
  return [(stemmed_tweets[idx], distances[idx]) for idx in sorted_indices[:n_similar]]

# Process each hashtag and print results using CountVectorizer
print("Using CountVectorizer:")
for i in range(len(stemmed_hashtags)):
  similar_tweets = find_similar_tweets_using_countvectorizer(stemmed_hashtags[i])
  print(f"Top 10 most similar tweets for {hashtag_list[i]}:")
  for tweet, score in similar_tweets:
    print(f"\t* {tweet} (Score: {score:.4f})")
# Out:
# Using CountVectorizer:
# Top 10 most original tweets for #RenewableEnergy:
# 	* ban free alcohol parliament hous might good start labor former cop member wide bay breath test vote futur alcohol abus lead disorderli name call behavior question (Score: 0.1614)
https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise_distances.html
#
# *   Define a function to retrieve top n_similar tweets for a given hashtag using sklearn's CountVectorizer. I chose to use a function since it helps with encapsulation and reusability of code.
#
# *   Create a vectorizer and fit it onto stemmed_tweets.
#
# *   Create a query vector of the hashtag and calculate similarity score using inverse Euclidean distance.
#
# *   Return top 10 similar tweets for a particular hashtag. I use a for loop to iterate over the indices of stemmed_hashtags and implement the function above. I then return each tweet with its corresponding score.
#
# ### Analysis
# The tweets extracted using CountVectorizer don't seem to be the best/ don't relate well to the specified tweet. This could be due to several reasons like data processing, similarity score method or vectorization method.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


# Function to retrieve top n_similar tweets for a given hashtag using TfidfVectorizer
def find_similar_tweets_using_Tfidf(hashtag, n_similar=10):

  # Define the N for N-grams
  N = 1

  # Initialize  TfidfVectorizer
  vectorizer = TfidfVectorizer(ngram_range=(N, N), lowercase=False, binary=True)

  # Fit vectorizer
  vectorizer.fit(stemmed_tweets)

  # Vectorize the hashtag using the fitted vectorizer
  queryVector = vectorizer.transform([hashtag.lower()]).toarray()

  # Calculate similarity using inverse Euclidean distance (sklearn implementation)
  distances = 1 / (1 + pairwise_distances(queryVector, vectorizer.transform(stemmed_tweets), metric='euclidean'))[0]

  # Sort indices
  sorted_indices = np.argsort(distances)

  # Return the top tweets and scores
  return [(stemmed_tweets[idx], distances[idx]) for idx in sorted_indices[:n_similar]]


# Process each hashtag and print results using TfidfVectorizer
print("Using TfidfVectorizer:")
for i in range(len(stemmed_hashtags)):
  similar_tweets = find_similar_tweets_using_Tfidf(stemmed_hashtags[i])
  print(f"Top 10 most similar tweets for {hashtag_list[i]}:")
  for tweet, score in similar_tweets:
    print(f"\t* {tweet} (Score: {score:.4f})")
# Out:
# Using TfidfVectorizer:
# Top 10 most similar tweets for ##RenewableEnergy:
# 	* support step forward peopl earth love earthli life inspir support eu climat (Score: 0.4142)
# 	* govern bereft moral bankrupt twist infight insati lust short long term ensur environment econom futur need (Score: 0.4142)
# 	* made supposedli independ given balanc senat power phoni suspect lose elect set help (Score: 0.4142)
# 	* massiv short fit mad boot torn apart team go bring niggl (Score: 0.4142)
# 	* bad vote experi today usual found despit issu mistaken fine home address list elector one sausag sizzl (Score: 0.4142)
# 	* whoever wish success lead countri parti everi time (Score: 0.4142)
# 	* go senat list tri find six worth vote tri find get six go singl issu (Score: 0.4142)
# 	* alp climat chang like choic actual thing happen desper need (Score: 0.4142)
# 	* bob current said shorten set danger preced religion stage close campaign day elect move make controversi faith part futur (Score: 0.4142)
# 	* progress left tri push countri road social current elect good never put roof head food virtu (Score: 0.4142)
# Top 10 most similar tweets for ##TaxLaws:
# 	* last elect stay hotel room watch elect coverag drank away (Score: 0.4142)
# 	* post carbon ross via (Score: 0.4142)
# 	* squiggl coin (Score: 0.4142)
# 	* elect might come dozen margin week hit trail seat alp via (Score: 0.4142)
# 	* fighter better predict (Score: 0.4142)
# 	* mani wind turbin elector (Score: 0.4142)
# 	* one nation prefer ration especi sinc liber primari (Score: 0.4142)
# 	* massiv short fit mad boot torn apart team go bring niggl (Score: 0.4142)
# 	* go senat list tri find six worth vote tri find get six go singl issu (Score: 0.4142)
# 	* govern bereft moral bankrupt twist infight insati lust short long term ensur environment econom futur need (Score: 0.4142)
# 	* alp climat chang like choic actual thing happen desper need (Score: 0.4142)
# 	* whoever wish success lead countri parti everi time (Score: 0.4142)
# 	* support step forward peopl earth love earthli life inspir support eu climat (Score: 0.4142)
# 	* bad vote experi today usual found despit issu mistaken fine home address list elector one sausag sizzl (Score: 0.4142)

# %% [markdown]
# In this code block, I do the following:
#
#
# *   Import sklearn's TfidfVectorizer: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
#
# *   Define a function to retrieve top n_similar tweets for a given hashtag using sklearn's TfidfVectorizer. I chose to use a function since it helps with encapsulation and reusability of code.
#
# *   Create a vectorizer and fit it onto stemmed_tweets.
#
# *   Create a query vector of the hashtag and calculate similarity score using inverse Euclidean distance.
#
# *   Return top 10 similar tweets for a particular hashtag using a for loop, iterating over each hashtag.
#
# ### Analysis
# Even using the TfidfVectorizer, the retrieved tweets don't seem to be the best/ don't relate well to the specified tweet. This could be due to several reasons like data processing, similarity score method or vectorization method.

# %%
from scipy.spatial.distance import euclidean
import gensim.downloader as api

# Load pre-trained GloVe embeddings
word_vectors = api.load("glove-wiki-gigaword-50")


# Function to generate average word embeddings for a sentence using GloVe vectors
def average_word_embeddings(sentence):
    words = sentence.split()
    embeddings = []
    for word in words:
        if word in word_vectors:
            embeddings.append(word_vectors[word])
    if len(embeddings) > 0:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(word_vectors.vector_size)


# Function to calculate inverse Euclidean distance between two vectors
def inverse_euclidean_distance(vector1, vector2):
    return 1 / (1 + euclidean(vector1, vector2))


word_vector_transformed_corpus = []
for tweet in stemmed_tweets:
  transformed_vector = average_word_embeddings(tweet)
  word_vector_transformed_corpus.append(transformed_vector)

# Process each hashtag and print results
for hashtag in stemmed_hashtags:
    # Vectorize the hashtag using GloVe word embeddings
    hashtag_embedding = average_word_embeddings(hashtag.lower())

    # Calculate inverse Euclidean distance between hashtag embedding and tweet embeddings
    similarities = [inverse_euclidean_distance(hashtag_embedding, tweet_embedding) for tweet_embedding in word_vector_transformed_corpus]

    # Sort indices by descending order of similarity score
    sorted_indices = np.argsort(similarities)[::-1]

    print(f"Top 10 most similar tweets for #{hashtag}:")
    for idx in sorted_indices[:10]:
        print(f"\t* {tweets[idx]} (Score: {similarities[idx]:.4f})")

# %% [markdown]
# Here I do the following:
# *   Load pre-trained GloVe embeddings
#
# *   Define a function to generate average word embeddings for a sentence using GloVe vectors
#
# *   Define a function to calculate inverse Euclidean distance between two vectors
# *   Create a word_vector_transformed_corpus by applying the average_word_embeddings function to each tweet
#
# *   Process each hashtag and print results
#
#
#
# ### Analysis
# The retrieved tweets using WordEmbedding vectorization technique definitely seems better than the results obtained using CountVectorizer and TfidfVectorizer. The tweets actually relate to the hashtag and the score also seems to carry an approriate weight. This is definitely the superior method for sentiment analysis of the tweets.
#
# ## Testing with a larger word bank

# %%
from scipy.spatial.distance import euclidean
import gensim.downloader as api

# Load pre-trained GloVe embeddings
word_vectors = api.load("glove-wiki-gigaword-200")


# Function to generate average word embeddings for a sentence using GloVe vectors
def average_word_embeddings(sentence):
    words = sentence.split()
    embeddings = []
    for word in words:
        if word in word_vectors:
            embeddings.append(word_vectors[word])
    if len(embeddings) > 0:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(word_vectors.vector_size)


# Function to calculate inverse Euclidean distance between two vectors
def inverse_euclidean_distance(vector1, vector2):
    return 1 / (1 + euclidean(vector1, vector2))


word_vector_transformed_corpus = []
for tweet in stemmed_tweets:
  transformed_vector = average_word_embeddings(tweet)
  word_vector_transformed_corpus.append(transformed_vector)

# Process each hashtag and print results
for hashtag in stemmed_hashtags:
    # Vectorize the hashtag using GloVe word embeddings
    hashtag_embedding = average_word_embeddings(hashtag.lower())

    # Calculate inverse Euclidean distance between hashtag embedding and tweet embeddings
    similarities = [inverse_euclidean_distance(hashtag_embedding, tweet_embedding) for tweet_embedding in word_vector_transformed_corpus]

    # Sort indices by descending order of similarity score
    sorted_indices = np.argsort(similarities)[::-1]

    print(f"Top 10 most similar tweets for #{hashtag}:")
    for idx in sorted_indices[:10]:
        print(f"\t* {tweets[idx]} (Score: {similarities[idx]:.4f})")
# Out:
# [==================================================] 100.0% 252.1/252.1MB downloaded
# Top 10 most similar tweets for #renew energi:
# 	* 4) Australian renewable energy agency
#  (Score: 1.0000)
# 	* with renewable energy and efficiencies technologies...
#  (Score: 1.0000)
# 	* ✅ abundant renewable energy generation potential
#  (Score: 0.3430)
# 	* Germany shows how shifting to renewable energy can backfire #auspol #ausvotes https://t.co/QiGxH2p1j1
#  (Score: 0.3100)
# 	* 2) Plan to have 50% renewable energy by 2030?
#  (Score: 0.3050)
# 	* Renewable energy is key to Australia’s economic growth.
#  (Score: 0.2970)
# 	* The cost of renewable energy continues to drop.
#  (Score: 0.2911)
# 	* 1) renewable energy target
#  (Score: 0.2899)
# 	* It is possible to live on 100% renewable energy .@ScottMorrisonMP .
#  (Score: 0.2815)
# 	* Renewable energy can't replace fossil fuels entirely https://t.co/HIR91pAK5j #billshorten #auspol #ausvotes
#  (Score: 0.2648)
# Top 10 most similar tweets for #tax law:
# 	* Keating: "L.A.W. Law tax cuts"
#  (Score: 1.0000)
# 	* ❌Accounting and legal fees for tax advice
#  (Score: 0.2867)
# 	* Liberals : Labor’s tax on tweeting. Labor’s tax on waking up. Labor’s tax on breathing. Labor’s tax on opening the door. Labor’s tax on farting. Labor’s tax on walking. Labor’s tax on setting the time on your watch. Labor’s tax on being ugly. Blah blah. Lol #auspol #ausvotes
#  (Score: 0.2561)
# 	* Morrison... TAX TAX TAX BILL BULLSHIT BILL TAX TAX TAX TAX
#  (Score: 0.2490)
# 	* “I’m taxing them less” says #Morrison who claims #Ausvotes19 isn’t a presidential race. “I’m”, not even “my government”. The hubris of the man! The ego! #TheDrum #AusVotes2019 #Auspol
#  (Score: 0.2464)
# 	* Bill mate, it is the tax paid to the ATO on profits by the company, that issued the dividend.
#  (Score: 0.2441)
# 	* Well he’s taxed my credulity #auspol #ausvotes https://t.co/mN8luWWkO8
#  (Score: 0.2435)
# 	* - whether he pays any tax
#  (Score: 0.2433)
# 	* Let's put a tax on 𝗹𝘆𝗶𝗻𝗴.
#  (Score: 0.2408)
# 	* Wealthy boomers getting a tax rebate on tax they haven't paid? Now that's where it's at 👍 #auspol #Ausvotes #AusVotes2019
#  (Score: 0.2408)
# Top 10 most similar tweets for #polit advertis:
# 	* #AGW is a political hoax.
#  (Score: 1.0000)
# 	* #Labor promises an independent EPA governed by science not political expediency. RKD
#  (Score: 1.0000)
# 	* @Twitter playing politics isn't your business!
#  (Score: 1.0000)
# 	* Australian women in politics have had enough.
#  (Score: 1.0000)
# 	* More women in politics
#  (Score: 1.0000)
# 	* Scott Morrison, becoming the political Jason Gillespie #nightwatchmen #ausvotes #auspol
#  (Score: 1.0000)
# 	* The smeagol of Australian Politics .....
#  (Score: 1.0000)
# 	* @HEB2205 @greenbus #orangecult🍊#PCMPP (Post Cathy McGowan Political Phase)  #irrelevant #fibs #voicesinthewilderness #beyondbelief #nopolicies #noagenda #nobudget #indivotes #auspol #emocracy #climatehysteria
#  (Score: 1.0000)
# 	* The political persecution of Christians Downunder ... #auspol 👇
#  (Score: 1.0000)
# 	* Australian politics in a word? Complacency.
#  (Score: 1.0000)
# Top 10 most similar tweets for #australia cricket:
# 	* Cricket is just Baseball on Valium #Australia #Auspol
#  (Score: 0.2212)
# 	* "People have baseball bats out for Mr Shorten".  Cricket Peter.  We have cricket bats out for Mr Shorten.  #unaustralian #auspol2019 #AusVotes2019 #ausvotes
#  (Score: 0.2051)
# 	* This is like watching the 1996/7 cricket World Cup where Sri Lanka won  #ausvotes
#  (Score: 0.2012)
# 	* This election is the equivalent of the Australian cricket team not being punished for ball tampering #auspol #ausvotes
#  (Score: 0.1887)
# 	* Lloyd Street PS in the background . Many a neighbourhood Cricket match played there in the 80s #oldneckofthewoods #ausvotes https://t.co/GgHBxN5vpy
#  (Score: 0.1865)
# 	* It keeps playing in my head when I think of #Morrison being dumped, as he certainly will. I mean, it's just not cricket 🏏
#  (Score: 0.1860)
# 	* For cricket commentators, we're very fine psephologists. Tune in for the knowledge.
#  (Score: 0.1847)
# 	* @TonyHWindsor @davidbewart @andrewprobyn Probyn is brainless orthodoxy exemplified. He's as insular Canberra as they come --right down to being the cricket team captain of the parliamentary press corp, as he proudly back-door bragged last night. Clueless. Sad! #auspol #ausvotes19
#  (Score: 0.1814)
# 	* Sadly most media treat #Auspol like a sporting event knowing no one wants to watch the Oz cricket team beat the under ten Sth Melbourne cricket team by 6 million runs. https://t.co/SKqwRpsFeC
#  (Score: 0.1784)
# 	* If today’s #election was a cricket match, entering the 5th day the @AustralianLabor party are 1/104 chasing 132 for victory. #AusVotes
#  (Score: 0.1779)
# Top 10 most similar tweets for #vote right:
# 	* Should migrants on visas have the right to vote in Australia? https://t.co/hCZaPgpb0R
#  (Score: 1.0000)
# 	* Should migrants on visas have the right to vote in Australia? | SBS Your Language https://t.co/2uP69ExvYk
#  (Score: 1.0000)
# 	* This is a welcomed policy and at the right time. Let's restore the Australian dream.  Vote Liberal.
#  (Score: 1.0000)
# 	* Vote For Australian's right to Rule, not Governed! https://t.co/MIj3gmPMsb
#  (Score: 1.0000)
# 	* @MatthewBevan You can vote anywhere in Australia right up to #May18. It's called AbsenteeVoting
#  (Score: 1.0000)
# 	* When you gotta vote for the right man.
#  (Score: 1.0000)
# 	* NO!!! Should migrants on visas have the right to vote in Australia? | SBS Your Language https://t.co/FcZWYEXEY8
#  (Score: 1.0000)
# 	* Should migrants on visas have the right to vote in Australia? | SBS Your Language https://t.co/1peCdXwKaq
#  (Score: 1.0000)
# 	* If you vote right of centre then you consider yourself more than others. #AUSVote19 #Election2019Results
#  (Score: 1.0000)
# 	* And exercise my right to vote too. #democracysausage #ausvotes https://t.co/eeWkMAYOft
#  (Score: 1.0000)
# Top 10 most similar tweets for #polit:
# 	* #AGW is a political hoax.
#  (Score: 1.0000)
# 	* #Labor promises an independent EPA governed by science not political expediency. RKD
#  (Score: 1.0000)
# 	* @Twitter playing politics isn't your business!
#  (Score: 1.0000)
# 	* Australian women in politics have had enough.
#  (Score: 1.0000)
# 	* More women in politics
#  (Score: 1.0000)
# 	* Scott Morrison, becoming the political Jason Gillespie #nightwatchmen #ausvotes #auspol
#  (Score: 1.0000)
# 	* The smeagol of Australian Politics .....
#  (Score: 1.0000)
# 	* @HEB2205 @greenbus #orangecult🍊#PCMPP (Post Cathy McGowan Political Phase)  #irrelevant #fibs #voicesinthewilderness #beyondbelief #nopolicies #noagenda #nobudget #indivotes #auspol #emocracy #climatehysteria
#  (Score: 1.0000)
# 	* The political persecution of Christians Downunder ... #auspol 👇
#  (Score: 1.0000)
# 	* Australian politics in a word? Complacency.
#  (Score: 1.0000)
# Top 10 most similar tweets for #trump:
# 	* The Trump effect. Polls suck. 😀
#  (Score: 1.0000)
# 	* 2015: Trump
#  (Score: 1.0000)
# 	* No chance for Trump 2016!  Trump wins.
#  (Score: 1.0000)
# 	* #AUSVote19 is Australia’s Trump / Brexit moment.
#  (Score: 1.0000)
# 	* (e.g. Trump 2016 &amp; Morrison 2019)
#  (Score: 1.0000)
# 	* And then Trump happened.
#  (Score: 1.0000)
# 	* Maybe this is our Trump moment? #ausvotes
#  (Score: 1.0000)
# 	* This is our Trump moment. #AUSVote19 #australiavotes
#  (Score: 1.0000)
# 	* The Australian Trump wins reelection!
#  (Score: 1.0000)
# 	* #ScuMo is Australia’s Trump / Brexit moment.
#  (Score: 1.0000)
# Top 10 most similar tweets for #abort:
# 	* Abortion rights? #australiadecides
#  (Score: 1.0000)
# 	* - Abortion laws revised
#  (Score: 1.0000)
# 	* Will you, or will you not, legalise abortion and increase funding for DV services if re-elected?
#  (Score: 1.0000)
# 	* I’m muting this Alabama abortion thing.
#  (Score: 1.0000)
# 	* Australia we have to eliminate abortion this election's weekend 😢🙏 https://t.co/d6HTd3ANVv
#  (Score: 0.1968)
# 	* It’s 2019 and abortion is still a criminal offence in NSW #auspol #abortion #NSW #2019laws #australianabortionlaws
#  (Score: 0.1912)
# 	* ABORTION IS MURDER
#  (Score: 0.1822)
# 	* The abortion laws in America. The pending results of the #auspol. 2019. What a f*cking time to be alive.
#  (Score: 0.1797)
# 	* @PerrettReport But Jannie, those Democrats who advocate for abortion as a constitutional right, are the very ones who claim capital punishment is Immoral. Do your research. #maga #auspol
#  (Score: 0.1762)
# 	* - abortion coming up FUCKING AGAIN as a fucking issue for fucks sake
#  (Score: 0.1710)
# Top 10 most similar tweets for #climat:
# 	* Scott Morrison was heckled by climate protesters after voting.
#  (Score: 1.0000)
# 	* @TonyAbbottMHR gives the 👍🏽 to #Labor’s Climate Policy
#  (Score: 1.0000)
# 	* Climate crisis. #ClimateCrisis #auspol https://t.co/3N0f6BSRhu
#  (Score: 1.0000)
# 	* This is a climate emergency https://t.co/WkKfeXGxKQ
#  (Score: 1.0000)
# 	* The UK has announced a climate emergency...
#  (Score: 1.0000)
# 	* The climate crisis has arrived https://t.co/daSNHom7cN
#  (Score: 1.0000)
# 	* Another climate bedwetting fail. https://t.co/QiqbfvAa5Z #FoxNews
#  (Score: 1.0000)
# 	* @murpharoo @gdgoz "Ashes in your mouth,eh? has he woken up to climate change. #auspol
#  (Score: 1.0000)
# 	* Didn't notice any climate emergency.
#  (Score: 1.0000)
# 	* Opposition says: “This election’s #1 issue is climate change.”
#  (Score: 1.0000)
# Top 10 most similar tweets for #ash:
# 	* “Your result will be ashes in your mouth.
#  (Score: 0.2074)
# 	* @MsVeruca Yeah, Strawman Morrisson, will flash and disappear, ans leave the ashes of his aspirations, in the dirt! #LNPfail #auspol
#  (Score: 0.2010)
# 	* #nrlcowboyseels #afllionscrows #NRLTitansBulldogs #AustraliaDecides #10yourvote Gabba Ash Taylor Bunnings Antony Green and Tom Stewart
#  (Score: 0.1997)
# 	* Only when the enemy succeeds in turning the spirit of the Jew into dust  and ashes in life, can he turn the Jew into dust and ashes in death. https://t.co/ZyVPXLFRdS
#  (Score: 0.1824)
# 	* Barnaby Joyce tells Jim Molan's Liberal rebels, “Your result will be ashes in your mouth.” #ausvotes #qldpol https://t.co/dFr9Gj3fMl
#  (Score: 0.1732)
# 	* Céline Dion - Ashes (from "Deadpool 2" Motion Picture Soundtrack) https://t.co/1ScjN8vzEU via @YouTube
#  (Score: 0.1604)
# 	* Why am I watching this? Also am not at all surprised that the there's a swing to the Libs. Let's burn it to the ground and scatter the ashes to the wind. #auspol https://t.co/Ub0TqpPmy0
#  (Score: 0.1525)
# 	* “...and the taste of #democracysausage will turn to ash in your mouth and then you will know, the debts to the planet can never be re-payed” #auspol https://t.co/h3Q4IV2bwd
#  (Score: 0.1510)
# 	* @ned2au No. The huge toxic plume created by the combustion of a minuscule 220 gallons of lube. We use more than that at Sydney Mardi Gras every year. #auspol
#  (Score: 0.1450)
# 	* Surprise victories usually turn to dust &amp; ashes quickly for the parties involved (Keating 93, Howard 04, Major 92) but they crush oppositions into shape of govt’s agenda #auspol #auspol2019
#  (Score: 0.1449)

# %%
from scipy.spatial.distance import euclidean
import gensim.downloader as api

# Load pre-trained GloVe embeddings
word_vectors = api.load("glove-wiki-gigaword-300")


# Function to generate average word embeddings for a sentence using GloVe vectors
def average_word_embeddings(sentence):
    words = sentence.split()
    embeddings = []
    for word in words:
        if word in word_vectors:
            embeddings.append(word_vectors[word])
    if len(embeddings) > 0:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(word_vectors.vector_size)


# Function to calculate inverse Euclidean distance between two vectors
def inverse_euclidean_distance(vector1, vector2):
    return 1 / (1 + euclidean(vector1, vector2))


word_vector_transformed_corpus = []
for tweet in stemmed_tweets:
  transformed_vector = average_word_embeddings(tweet)
  word_vector_transformed_corpus.append(transformed_vector)

# Process each hashtag and print results
for hashtag in stemmed_hashtags:
    # Vectorize the hashtag using GloVe word embeddings
    hashtag_embedding = average_word_embeddings(hashtag.lower())

    # Calculate inverse Euclidean distance between hashtag embedding and tweet embeddings
    similarities = [inverse_euclidean_distance(hashtag_embedding, tweet_embedding) for tweet_embedding in word_vector_transformed_corpus]

    # Sort indices by descending order of similarity score
    sorted_indices = np.argsort(similarities)[::-1]

    print(f"Top 10 most similar tweets for #{hashtag}:")
    for idx in sorted_indices[:10]:
        print(f"\t* {tweets[idx]} (Score: {similarities[idx]:.4f})")
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded
# Top 10 most similar tweets for #renew energi:
# 	* 4) Australian renewable energy agency
#  (Score: 1.0000)
# 	* with renewable energy and efficiencies technologies...
#  (Score: 1.0000)
# 	* ✅ abundant renewable energy generation potential
#  (Score: 0.2942)
# 	* 2) Plan to have 50% renewable energy by 2030?
#  (Score: 0.2932)
# 	* Germany shows how shifting to renewable energy can backfire #auspol #ausvotes https://t.co/QiGxH2p1j1
#  (Score: 0.2877)
# 	* Renewable energy is key to Australia’s economic growth.
#  (Score: 0.2862)
# 	* The cost of renewable energy continues to drop.
#  (Score: 0.2796)
# 	* 1) renewable energy target
#  (Score: 0.2736)
# 	* It is possible to live on 100% renewable energy .@ScottMorrisonMP .
#  (Score: 0.2654)
# 	* Renewable energy can't replace fossil fuels entirely https://t.co/HIR91pAK5j #billshorten #auspol #ausvotes
#  (Score: 0.2537)
# Top 10 most similar tweets for #tax law:
# 	* Keating: "L.A.W. Law tax cuts"
#  (Score: 1.0000)
# 	* ❌Accounting and legal fees for tax advice
#  (Score: 0.2643)
# 	* Liberals : Labor’s tax on tweeting. Labor’s tax on waking up. Labor’s tax on breathing. Labor’s tax on opening the door. Labor’s tax on farting. Labor’s tax on walking. Labor’s tax on setting the time on your watch. Labor’s tax on being ugly. Blah blah. Lol #auspol #ausvotes
#  (Score: 0.2480)
# 	* Morrison... TAX TAX TAX BILL BULLSHIT BILL TAX TAX TAX TAX
#  (Score: 0.2384)
# 	* Wealthy boomers getting a tax rebate on tax they haven't paid? Now that's where it's at 👍 #auspol #Ausvotes #AusVotes2019
#  (Score: 0.2347)
# 	* “I’m taxing them less” says #Morrison who claims #Ausvotes19 isn’t a presidential race. “I’m”, not even “my government”. The hubris of the man! The ego! #TheDrum #AusVotes2019 #Auspol
#  (Score: 0.2343)
# 	* Well he’s taxed my credulity #auspol #ausvotes https://t.co/mN8luWWkO8
#  (Score: 0.2325)
# 	* Moreover, Liberals were offering tax cuts, and not only did Labor denounce them, they wanted to increase taxes/remove deductions for people the tax cuts were aimed at!!!!!
#  (Score: 0.2297)
# 	* Why would @JoshFrydenberg worry about taxing inspiration.
#  (Score: 0.2287)
# 	* @66Benno @BillDobell @samanthamaiden According to the tax department, the franking credits refund isn't a tax loophole &amp; never has been. It's just the greedy #ALP taxing these retirees' dividends at 30%, even if their income falls below the taxable threshold. It's Theft.
#  (Score: 0.2283)
# Top 10 most similar tweets for #polit advertis:
# 	* Political balconies in Warringah #ausvotes https://t.co/ZGT3Y4ol9V
#  (Score: 1.0000)
# 	* "I'm proud we argued what was right, not what was easy. This is what politics should be in our country."
#  (Score: 1.0000)
# 	* Queensland is experiencing the political equivalent of an Engadine Maccas episode... FFS 💩🤢😩
#  (Score: 1.0000)
# 	* HERE IS YOUR CHANCE TO DO A POLITICAL ESSAY.
#  (Score: 1.0000)
# 	* - It's all political
#  (Score: 1.0000)
# 	* Scott Morrison, becoming the political Jason Gillespie #nightwatchmen #ausvotes #auspol
#  (Score: 1.0000)
# 	* Political football. Very friendly booth. #auspol #AusVotes2019 https://t.co/uhHTGFMIaK
#  (Score: 1.0000)
# 	* No more terrible #clivepalmer political ads...
#  (Score: 1.0000)
# 	* Does @Adelaide_FC have official positions on political issues?
#  (Score: 1.0000)
# 	* @anusha_srini @smh How American is Australian politics becoming? We don't have a 'First Lady'.
#  (Score: 1.0000)
# Top 10 most similar tweets for #australia cricket:
# 	* Cricket is just Baseball on Valium #Australia #Auspol
#  (Score: 0.2050)
# 	* "People have baseball bats out for Mr Shorten".  Cricket Peter.  We have cricket bats out for Mr Shorten.  #unaustralian #auspol2019 #AusVotes2019 #ausvotes
#  (Score: 0.1910)
# 	* This is like watching the 1996/7 cricket World Cup where Sri Lanka won  #ausvotes
#  (Score: 0.1845)
# 	* It keeps playing in my head when I think of #Morrison being dumped, as he certainly will. I mean, it's just not cricket 🏏
#  (Score: 0.1789)
# 	* This election is the equivalent of the Australian cricket team not being punished for ball tampering #auspol #ausvotes
#  (Score: 0.1752)
# 	* Lloyd Street PS in the background . Many a neighbourhood Cricket match played there in the 80s #oldneckofthewoods #ausvotes https://t.co/GgHBxN5vpy
#  (Score: 0.1718)
# 	* For cricket commentators, we're very fine psephologists. Tune in for the knowledge.
#  (Score: 0.1687)
# 	* @TonyHWindsor @davidbewart @andrewprobyn Probyn is brainless orthodoxy exemplified. He's as insular Canberra as they come --right down to being the cricket team captain of the parliamentary press corp, as he proudly back-door bragged last night. Clueless. Sad! #auspol #ausvotes19
#  (Score: 0.1678)
# 	* Sadly most media treat #Auspol like a sporting event knowing no one wants to watch the Oz cricket team beat the under ten Sth Melbourne cricket team by 6 million runs. https://t.co/SKqwRpsFeC
#  (Score: 0.1676)
# 	* If today’s #election was a cricket match, entering the 5th day the @AustralianLabor party are 1/104 chasing 132 for victory. #AusVotes
#  (Score: 0.1669)
# Top 10 most similar tweets for #vote right:
# 	* Should migrants on visas have the right to vote in Australia? https://t.co/7AvVojp4ce
#  (Score: 1.0000)
# 	* This is a welcomed policy and at the right time. Let's restore the Australian dream.  Vote Liberal.
#  (Score: 1.0000)
# 	* Should migrants on visas have the right to vote in Australia? | SBS Your Language https://t.co/1peCdXwKaq
#  (Score: 1.0000)
# 	* Should migrants on visas have the right to vote in Australia? | SBS Your Language https://t.co/2uP69ExvYk
#  (Score: 1.0000)
# 	* Claiming my constitutional right on voting day.
#  (Score: 1.0000)
# 	* @abcnews @TonyAbbottMHR He’s right don’t vote for him. #auspol #AUSVote19
#  (Score: 1.0000)
# 	* Vote For Australian's right to Rule, not Governed! https://t.co/MIj3gmPMsb
#  (Score: 1.0000)
# 	* NO!!! Should migrants on visas have the right to vote in Australia? | SBS Your Language https://t.co/FcZWYEXEY8
#  (Score: 1.0000)
# 	* And exercise my right to vote too. #democracysausage #ausvotes https://t.co/eeWkMAYOft
#  (Score: 1.0000)
# 	* When you gotta vote for the right man.
#  (Score: 1.0000)
# Top 10 most similar tweets for #polit:
# 	* Political balconies in Warringah #ausvotes https://t.co/ZGT3Y4ol9V
#  (Score: 1.0000)
# 	* "I'm proud we argued what was right, not what was easy. This is what politics should be in our country."
#  (Score: 1.0000)
# 	* Queensland is experiencing the political equivalent of an Engadine Maccas episode... FFS 💩🤢😩
#  (Score: 1.0000)
# 	* HERE IS YOUR CHANCE TO DO A POLITICAL ESSAY.
#  (Score: 1.0000)
# 	* - It's all political
#  (Score: 1.0000)
# 	* Scott Morrison, becoming the political Jason Gillespie #nightwatchmen #ausvotes #auspol
#  (Score: 1.0000)
# 	* Political football. Very friendly booth. #auspol #AusVotes2019 https://t.co/uhHTGFMIaK
#  (Score: 1.0000)
# 	* No more terrible #clivepalmer political ads...
#  (Score: 1.0000)
# 	* Does @Adelaide_FC have official positions on political issues?
#  (Score: 1.0000)
# 	* @anusha_srini @smh How American is Australian politics becoming? We don't have a 'First Lady'.
#  (Score: 1.0000)
# Top 10 most similar tweets for #trump:
# 	* No chance for Trump 2020!
#  (Score: 1.0000)
# 	* This is #auspol 's Trump mom.
#  (Score: 1.0000)
# 	* meanwhile other issues trump
#  (Score: 1.0000)
# 	* @snowycats @phbarratt Australia's Trump Brexit moment.
#  (Score: 1.0000)
# 	* This is our Trump moment.
#  (Score: 1.0000)
# 	* @DrWevil @TheCalebBond @Qlder #AUSVote19 is Australia’s Trump / Brexit moment.
#  (Score: 1.0000)
# 	* Maybe this is our Trump moment? #ausvotes
#  (Score: 1.0000)
# 	* America under Trump is a rogue state.
#  (Score: 1.0000)
# 	* self-interest appears to trump wider interests ..... appalling ....#AustraliaDecides
#  (Score: 1.0000)
# 	* Trump immigration plan.
#  (Score: 1.0000)
# Top 10 most similar tweets for #abort:
# 	* Abortion rights? #australiadecides
#  (Score: 1.0000)
# 	* - Abortion laws revised
#  (Score: 1.0000)
# 	* Will you, or will you not, legalise abortion and increase funding for DV services if re-elected?
#  (Score: 1.0000)
# 	* I’m muting this Alabama abortion thing.
#  (Score: 1.0000)
# 	* Australia we have to eliminate abortion this election's weekend 😢🙏 https://t.co/d6HTd3ANVv
#  (Score: 0.1869)
# 	* It’s 2019 and abortion is still a criminal offence in NSW #auspol #abortion #NSW #2019laws #australianabortionlaws
#  (Score: 0.1802)
# 	* ABORTION IS MURDER
#  (Score: 0.1741)
# 	* The abortion laws in America. The pending results of the #auspol. 2019. What a f*cking time to be alive.
#  (Score: 0.1654)
# 	* @PerrettReport But Jannie, those Democrats who advocate for abortion as a constitutional right, are the very ones who claim capital punishment is Immoral. Do your research. #maga #auspol
#  (Score: 0.1639)
# 	* @miniminter Pretty shit, Australia just elected their oppressors again in a federal election and Alabama + Ohio have passed crazy abortion laws...
#  (Score: 0.1597)
# Top 10 most similar tweets for #climat:
# 	* So climate insurrection?
#  (Score: 1.0000)
# 	* Committed to climate change. 🤔 #WarringahVotes  #auspol #ausvotes https://t.co/QyuifdolSK
#  (Score: 1.0000)
# 	* Fuck off Tones. There IS no economy if we don’t do anything about Climate Change. #ausvotes
#  (Score: 1.0000)
# 	* Climate change...
#  (Score: 1.0000)
# 	* Climate crisis. #ClimateCrisis #auspol https://t.co/3N0f6BSRhu
#  (Score: 1.0000)
# 	* @MurrayMcGee3 @tanya_plibersek A changing climate is the future. In this election, Australia failed its children.
#  (Score: 1.0000)
# 	* It’s the climate economy, stupid.#ActOnClimate #auspol
#  (Score: 1.0000)
# 	* And by ‘I’ he means the climate right? #ausvotes https://t.co/V8Qd9BlNsQ
#  (Score: 1.0000)
# 	* 6. Climate deniers
#  (Score: 1.0000)
# 	* The climate emergency demands immediate action.
#  (Score: 1.0000)
# Top 10 most similar tweets for #ash:
# 	* “Your result will be ashes in your mouth.
#  (Score: 0.1998)
# 	* @MsVeruca Yeah, Strawman Morrisson, will flash and disappear, ans leave the ashes of his aspirations, in the dirt! #LNPfail #auspol
#  (Score: 0.1907)
# 	* #nrlcowboyseels #afllionscrows #NRLTitansBulldogs #AustraliaDecides #10yourvote Gabba Ash Taylor Bunnings Antony Green and Tom Stewart
#  (Score: 0.1884)
# 	* Only when the enemy succeeds in turning the spirit of the Jew into dust  and ashes in life, can he turn the Jew into dust and ashes in death. https://t.co/ZyVPXLFRdS
#  (Score: 0.1777)
# 	* Barnaby Joyce tells Jim Molan's Liberal rebels, “Your result will be ashes in your mouth.” #ausvotes #qldpol https://t.co/dFr9Gj3fMl
#  (Score: 0.1595)
# 	* Céline Dion - Ashes (from "Deadpool 2" Motion Picture Soundtrack) https://t.co/1ScjN8vzEU via @YouTube
#  (Score: 0.1553)
# 	* Why am I watching this? Also am not at all surprised that the there's a swing to the Libs. Let's burn it to the ground and scatter the ashes to the wind. #auspol https://t.co/Ub0TqpPmy0
#  (Score: 0.1475)
# 	* “...and the taste of #democracysausage will turn to ash in your mouth and then you will know, the debts to the planet can never be re-payed” #auspol https://t.co/h3Q4IV2bwd
#  (Score: 0.1444)
# 	* Surprise victories usually turn to dust &amp; ashes quickly for the parties involved (Keating 93, Howard 04, Major 92) but they crush oppositions into shape of govt’s agenda #auspol #auspol2019
#  (Score: 0.1428)
# 	* Adani and Palmers coal have an energy content of only 4,950kcal and 26% ash content,that is only 10% above the average quality of domestic Indian thermal coal in terms of energy content but has to travel 10x the distance. It's not viable #Auspol
#  (Score: 0.1399)

# %% [markdown]
# ### Analysis
#
# Both glove-wiki-gigaword-200 and glove-wiki-gigaword-300 seem to deliver similar results. glove-wiki-gigaword-200 definitely runs faster due to lower dimensionality, but it also captures less nuanced semantic information. The relevance of tweets gathered by glove-wiki-gigaword-300 seem to be more appropriate for the task.
